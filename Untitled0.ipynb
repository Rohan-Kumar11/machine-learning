# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('student_scores.csv')

# %%
df.shape
# Out:
# (100, 2)

# %%
df.head()
# Out:
#    hours  scores
# 0   3.75   38.37
# 1   9.51   92.11
# 2   7.32   74.12
# 3   5.99   40.02
# 4   1.56   13.40

# %%
data=df[['scores']]
target=df['hours']

# %%
data
# Out:
# 0     38.37
# 1     92.11
# 2     74.12
# 3     40.02
# 4     13.40
#       ...
# 95    41.24
# 96    51.53
# 97    46.21
# 98     5.27
# 99    19.07
# Name: scores, Length: 100, dtype: float64

# %%
target
# Out:
# 0     3.75
# 1     9.51
# 2     7.32
# 3     5.99
# 4     1.56
#       ...
# 95    4.94
# 96    5.23
# 97    4.28
# 98    0.25
# 99    1.08
# Name: hours, Length: 100, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(data,target, train_size=0.7, random_state=0)

# %%
print(X_train.shape, Y_train.shape)
# Out:
# (70,) (70,)

# %%
print(X_test.shape, Y_test.shape)
# Out:
# (30,) (30,)

# %%
print(X_train)
# Out:
# 60     31.07
# 80    100.00
# 90     20.22
# 68     10.10
# 51     71.84
#        ...
# 96     51.53
# 67     82.05
# 64     30.37
# 47     37.98
# 44     33.81
# Name: scores, Length: 70, dtype: float64

# %%
print(Y_train)
# Out:
# 60    3.89
# 80    8.63
# 90    1.20
# 68    0.75
# 51    7.75
#       ...
# 96    5.23
# 67    8.02
# 64    2.81
# 47    5.20
# 44    2.59
# Name: hours, Length: 70, dtype: float64

# %%
print(X_test)
# Out:
# 26    16.57
# 86    84.59
# 2     74.12
# 55    92.89
# 75    76.36
# 93    48.56
# 16    23.38
# 73    84.47
# 54    44.29
# 95    41.24
# 53    84.47
# 92    73.65
# 78    38.73
# 13    26.33
# 7     81.42
# 30    79.66
# 22    29.25
# 24    31.45
# 33    94.16
# 8     52.02
# 43    98.42
# 62    91.04
# 3     40.02
# 71     6.70
# 45    57.21
# 48    60.57
# 6     20.58
# 99    19.07
# 82    21.19
# 76    70.30
# Name: scores, dtype: float64

# %%
print(Y_test)
# Out:
# 26    2.00
# 86    7.30
# 2     7.32
# 55    9.22
# 75    7.29
# 93    5.61
# 16    3.04
# 73    8.15
# 54    5.98
# 95    4.94
# 53    8.95
# 92    7.61
# 78    3.58
# 13    2.12
# 7     8.66
# 30    6.08
# 22    2.92
# 24    4.56
# 33    9.49
# 8     6.01
# 43    9.09
# 62    8.29
# 3     5.99
# 71    1.99
# 45    6.63
# 48    5.47
# 6     0.58
# 99    1.08
# 82    3.31
# 76    7.71
# Name: hours, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print('y intercept:',regressor.intercept_)
print('slope:',regressor.coef_)
# Out:
# y intercept: 0.007110926933705741
# slope: [0.09843097]

# %%
Y_test_pred=regressor.predict(X_test)

# %%
temp_df=pd.DataFrame({'Actual':Y_test,'Predicted':Y_test_pred})

# %%
import seaborn as sns

# %%
sns.histplot(Y_test,color='red',bins=5,alpha=0.5)
sns.histplot(Y_test_pred,color='blue',bins=5,alpha=0.5)
# Out:
# <Axes: xlabel='hours', ylabel='Count'>

# %%
from sklearn import metrics

# %%
print('Root Mean squared error:',np.sqrt(metrics.mean_squared_error(Y_test,Y_test_pred)))
# Out:
# Root Mean squared error: 0.9308623308611516

# %%
print(metrics.r2_score(Y_test,Y_test_pred))
# Out:
# 0.8711375856470022
